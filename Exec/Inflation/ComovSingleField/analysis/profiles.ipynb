# %%
import matplotlib.pyplot as plt
import numpy as np
#from scipy.integrate import solve_ivp

# %%
f1 = open("../data", "r")

# %%
phi1 = []
phi2 = []

# %%
n = 0
f1.readline()
for line in f1.readlines():
    n = n+1
    if n < 65:
        fields = line.split()
        phi1.append(   float(fields[0]))
    if n > 65:
        fields = line.split()
        phi2.append(   float(fields[0]))

# %%
f1.close()

# %%
phi2
# Out:
# [1.000074576,
#  1.000074576,
#  1.037404244,
#  1.037404244,
#  1.072894111,
#  1.072894111,
#  1.104857691,
#  1.104857691,
#  1.131785599,
#  1.131785599,
#  1.152491431,
#  1.152491431,
#  1.166178993,
#  1.166178993,
#  1.172477063,
#  1.172477063,
#  1.171449312,
#  1.171449312,
#  1.163574646,
#  1.163574646,
#  1.149699401,
#  1.149699401,
#  1.130965641,
#  1.130965641,
#  1.108721615,
#  1.108721615,
#  1.084421698,
#  1.084421698,
#  1.059523729,
#  1.059523729,
#  1.035391699,
#  1.035391699,
#  1.013211037,
#  1.013211037,
#  0.9939224971,
#  0.9939224971,
#  0.9781789627,
#  0.9781789627,
#  0.9663274013,
#  0.9663274013,
#  0.9584160854,
#  0.9584160854,
#  0.954225035,
#  0.954225035,
#  0.9533157626,
#  0.9533157626,
#  0.955094887,
#  0.955094887,
#  0.9588851926,
#  0.9588851926,
#  0.963997304,
#  0.963997304,
#  0.9697953543,
#  0.9697953543,
#  0.9757508252,
#  0.9757508252,
#  0.9814800367,
#  0.9814800367,
#  0.9867624565,
#  0.9867624565,
#  0.991538911,
# ...

# %%
steps1 = np.linspace(0., 1, 64)
steps2 = np.linspace(0., 1, 128)

# %%
#%matplotlib ipympl
# %matplotlib widget
plt.scatter(steps1,phi1)
#plt.scatter(steps2,phi2)
plt.xlabel("$x$")
plt.ylabel("$\phi$")
# Out:
# Text(0, 0.5, '$\\phi$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#%matplotlib ipympl
# %matplotlib widget
#plt.scatter(steps1,phi1)
plt.scatter(steps2,phi2)
plt.xlabel("$x$")
plt.ylabel("$\phi$")
# Out:
# Text(0, 0.5, '$\\phi$')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
