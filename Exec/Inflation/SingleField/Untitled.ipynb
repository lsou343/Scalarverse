# %%
import yt
import numpy as np

from yt.frontends.boxlib.api import NyxDataset, AMReXDataset

# %%
print(yt.__version__)
# Out:
# 4.4.0

# %%
file1 = "plt00000"
file2 = "plt00001"

ds = AMReXDataset(file1)
ds1 = AMReXDataset(file2)
# Out:
# yt : [INFO     ] 2025-07-04 13:35:09,127 Parameters: current_time              = 0.0
# yt : [INFO     ] 2025-07-04 13:35:09,127 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2025-07-04 13:35:09,128 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-07-04 13:35:09,129 Parameters: domain_right_edge         = [20. 20. 20.]
# yt : [INFO     ] 2025-07-04 13:35:09,149 Parameters: current_time              = 0.05
# yt : [INFO     ] 2025-07-04 13:35:09,150 Parameters: domain_dimensions         = [256 256 256]
# yt : [INFO     ] 2025-07-04 13:35:09,150 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-07-04 13:35:09,151 Parameters: domain_right_edge         = [20. 20. 20.]

# %%
ds.field_list
ds.derived_field_list
# Out:
# [('boxlib', 'KGf'),
#  ('boxlib', 'KGfVpr'),
#  ('boxlib', 'KGfdens'),
#  ('boxlib', 'KGfpr'),
#  ('boxlib', 'KGfv'),
#  ('boxlib', 'cell_volume'),
#  ('boxlib', 'dx'),
#  ('boxlib', 'dy'),
#  ('boxlib', 'dz'),
#  ('boxlib', 'path_element_x'),
#  ('boxlib', 'path_element_y'),
#  ('boxlib', 'path_element_z'),
#  ('boxlib', 'volume'),
#  ('boxlib', 'x'),
#  ('boxlib', 'y'),
#  ('boxlib', 'z'),
#  ('gas', 'cell_volume'),
#  ('gas', 'dx'),
#  ('gas', 'dy'),
#  ('gas', 'dz'),
#  ('gas', 'path_element_x'),
#  ('gas', 'path_element_y'),
#  ('gas', 'path_element_z'),
#  ('gas', 'volume'),
#  ('gas', 'x'),
#  ('gas', 'y'),
#  ('gas', 'z'),
#  ('index', 'cell_volume'),
#  ('index', 'cylindrical_radius'),
#  ('index', 'cylindrical_theta'),
#  ('index', 'cylindrical_z'),
#  ('index', 'dx'),
#  ('index', 'dy'),
#  ('index', 'dz'),
#  ('index', 'grid_indices'),
#  ('index', 'grid_level'),
#  ('index', 'morton_index'),
#  ('index', 'ones'),
#  ('index', 'ones_over_dx'),
# ...

# %%
#ds.print_stats()
ds.print_stats()
# Out:
# level	# grids	       # cells	     # cells^3
# ----------------------------------------------
#   0	   512	      16777216	           256
# ----------------------------------------------
#    	   512	      16777216
#
#
# t = 0.00000000e+00 code_time = 0.00000000e+00 s = 0.00000000e+00 yr
#
# Smallest Cell:
# 	Width: 2.532e-26 Mpc
# 	Width: 2.532e-20 pc
# 	Width: 5.222e-15 AU
# 	Width: 7.812e-02 cm

# %%
#def _resq(field,data):
#    return data["AxRe"]*data["AxRe"]
#def _imsq(field,data):
#    return data["AxIm"]*data["AxIm"]
#def _densq(field,data):
#    return data["AxRe"]*data["AxRe"] + data["AxIm"]*data["AxIm"]
#def _invdensq(field,data):
#    return 1./(data["AxRe"]*data["AxRe"] + data["AxIm"]*data["AxIm"])
#def _invdens(field,data):
#    return 1./data["AxDens"]
#ds.add_field(("boxlib","AxDenSq"), function=_densq, sampling_type="local", units="dimensionless",)
#ds.add_field(("boxlib","InvAxDenSq"), function=_invdensq, sampling_type="local", units="dimensionless",)

# %%
mi, ma = ds.all_data().quantities.extrema("KGf")
print(mi)
print(ma)
# Out:
# 0.023252055700619126 dimensionless
# 0.023252693812717076 dimensionless

# %%
#slc = yt.ProjectionPlot(ds, "z", "AxDens")
#slc = yt.SlicePlot(ds, "z", "AxDenSq")
#slc = yt.SlicePlot(ds, "z", "axion_phase", center=[0.,0.,0.15])
slc = yt.SlicePlot(ds, "z", "KGfdens")
slc.zoom(1)
slc.set_log("KGfdens", False)
#slc.annotate_grids()
slc.show()
# Out:
# yt : [INFO     ] 2025-07-04 13:35:11,485 xlim = 0.000000 20.000000
# yt : [INFO     ] 2025-07-04 13:35:11,485 ylim = 0.000000 20.000000
# yt : [INFO     ] 2025-07-04 13:35:11,487 xlim = 0.000000 20.000000
# yt : [INFO     ] 2025-07-04 13:35:11,487 ylim = 0.000000 20.000000
# yt : [INFO     ] 2025-07-04 13:35:11,489 Making a fixed resolution buffer of (('boxlib', 'KGfdens')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
#slc = yt.ProjectionPlot(ds, "z", "AxDens")
#slc = yt.SlicePlot(ds, "z", "AxDenSq")
#slc = yt.SlicePlot(ds, "z", "axion_phase", center=[0.,0.,0.15])
slc = yt.SlicePlot(ds1, "z", "KGf")
slc.zoom(1)
slc.set_log("KGf", False)
#slc.annotate_grids()
slc.show()
# Out:
# yt : [INFO     ] 2025-02-03 22:04:20,257 xlim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:20,258 ylim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:20,261 xlim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:20,261 ylim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:20,263 Making a fixed resolution buffer of (('boxlib', 'KGf')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
#slc = yt.ProjectionPlot(ds, "z", "AxDens")
#slc = yt.SlicePlot(ds, "z", "AxDenSq")
#slc = yt.SlicePlot(ds, "z", "axion_phase", center=[0.,0.,0.15])
slc = yt.SlicePlot(ds, "z", "KGfv")
slc.zoom(1)
slc.set_log("KGfv", False)
#slc.annotate_grids()
slc.show()
# Out:
# yt : [INFO     ] 2025-02-03 22:04:20,956 xlim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:20,957 ylim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:20,960 xlim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:20,961 ylim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:20,962 Making a fixed resolution buffer of (('boxlib', 'KGfv')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
#slc = yt.SlicePlot(ds, "z", "axion_phase", center=[0.,0.,0.15])
slc1 = yt.SlicePlot(ds1, "z", "KGf")
slc1.zoom(1)
slc1.set_log("KGf", False)
#slc.annotate_grids()
slc1.show()
# Out:
# yt : [INFO     ] 2025-02-03 22:04:26,744 xlim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:26,745 ylim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:26,747 xlim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:26,748 ylim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:26,749 Making a fixed resolution buffer of (('boxlib', 'KGf')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slc1 = yt.SlicePlot(ds1, "z", "KGfv")
slc1.zoom(1)
slc1.set_log("KGfv", False)
#slc.annotate_grids()
slc1.show()
# Out:
# yt : [INFO     ] 2025-02-03 22:04:27,344 xlim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:27,345 ylim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:27,348 xlim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:27,348 ylim = 0.000000 20.000000
# yt : [INFO     ] 2025-02-03 22:04:27,350 Making a fixed resolution buffer of (('boxlib', 'KGfv')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
